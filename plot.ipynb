# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
learning_curves = np.load('Results/DefaultExp/learning_curve.npz')
ROC_curves = np.load('Results/DefaultExp/ROC_curve1.npz')
ROC_curves1 = np.load('Results/DefaultExp/ROC_curveDropout.npz')
ROC_curves2 = np.load('Results/DefaultExp/ROC_curveDropoutPlus.npz')

# %%
fig = plt.figure()

N = len(learning_curves['losses_train'])
x = np.arange(1,N+1)
plt.plot(x,learning_curves['losses_train'], label='train', marker='o', fillstyle='none')
plt.plot(x,learning_curves['losses_val'], label='val', marker = "o", fillstyle = "none")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Learning curves')
plt.legend()
plt.savefig(f"LearnigCurve_{N}epochs_dropoutPlus.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig = plt.figure()

plt.plot(ROC_curves['FPR'], ROC_curves['TPR'], marker='o', fillstyle='none')
plt.plot([0,1],[0,1], '--', fillstyle = "none")
plt.plot(ROC_curves['FPR'][7], ROC_curves['TPR'][7], color='red', marker='x', linestyle='', fillstyle='none', label='Chosen Threshold (0.5)')
plt.plot(ROC_curves1['FPR'], ROC_curves1['TPR'], marker='o', fillstyle='none')
plt.plot(ROC_curves2['FPR'], ROC_curves2['TPR'], marker='o', fillstyle='none')
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.grid()
plt.show()
